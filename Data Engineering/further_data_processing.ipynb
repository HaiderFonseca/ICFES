# %%
from dotenv import load_dotenv
import psycopg2
import os
import pandas as pd

load_dotenv(dotenv_path='../Despliegue/.env')
USER=os.getenv('USER_DB')
PASSWORD=os.getenv('PASSWORD')
HOST=os.getenv('HOST')
PORT=os.getenv('PORT')
DBNAME=os.getenv('DBNAME')

engine = psycopg2.connect(
    dbname=DBNAME,
    user=USER,
    password=PASSWORD,
    host=HOST,
    port=PORT
)
cursor = engine.cursor()
query = "SELECT * FROM datos;"
df = pd.read_sql(query, engine)
df
# Out:
# /var/folders/9y/__pdhdy15bs2zh7r1m4dhnm40000gp/T/ipykernel_40326/3788612867.py:22: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, engine)
#         periodo colegio_area colegio_bilingue colegio_calendario  \
# 0         20172       URBANO                N                  A
# 1         20172        RURAL                                   A
# 2         20162       URBANO                N                  A
# 3         20152       URBANO                N                  A
# 4         20142       URBANO                N                  A
# ...         ...          ...              ...                ...
# 4496027   20194       URBANO                N                  A
# 4496028   20151       URBANO                S                  B
# 4496029   20152       URBANO                N                  A
# 4496030   20142       URBANO                N                  A
# 4496031   20142       URBANO                N                  A
#
#           colegio_caracter colegio_departamento colegio_genero  \
# 0        TÉCNICO/ACADÉMICO              BOLIVAR          MIXTO
# 1                ACADÉMICO         CUNDINAMARCA          MIXTO
# 2                ACADÉMICO               BOGOTA          MIXTO
# 3                ACADÉMICO              BOLIVAR          MIXTO
# 4                ACADÉMICO              BOLIVAR          MIXTO
# ...                    ...                  ...            ...
# 4496027          ACADÉMICO              BOLIVAR          MIXTO
# 4496028          ACADÉMICO               BOGOTA          MIXTO
# 4496029            TÉCNICO               BOYACA          MIXTO
# 4496030          ACADÉMICO              BOLIVAR          MIXTO
# 4496031            TÉCNICO              BOLIVAR          MIXTO
#
#         colegio_jornada colegio_municipio colegio_naturaleza  ...  \
# 0                 TARDE         CARTAGENA            OFICIAL  ...
# 1                 UNICA         GUATAVITA            OFICIAL  ...
# 2                MAÑANA       BOGOTÁ D.C.            OFICIAL  ...
# 3                MAÑANA         CARTAGENA         NO OFICIAL  ...
# 4                 TARDE            ARJONA            OFICIAL  ...
# ...                 ...               ...                ...  ...
# 4496027           TARDE    SAN ESTANISLAO            OFICIAL  ...
# 4496028        COMPLETA       BOGOTÁ D.C.         NO OFICIAL  ...
# 4496029        COMPLETA         ZETAQUIRA            OFICIAL  ...
# 4496030          MAÑANA          PINILLOS            OFICIAL  ...
# 4496031          MAÑANA         CARTAGENA            OFICIAL  ...
#
#         estudiante_departamento estudiante_fechanacimiento estudiante_genero  \
# 0                       BOLIVAR                       None                 M
# 1                  CUNDINAMARCA                       None                 F
# 2                        BOGOTÁ                       None                 M
# 3                       BOLIVAR                       None                 F
# 4                       BOLIVAR                       None                 M
# ...                         ...                        ...               ...
# 4496027                 BOLIVAR                       None                 F
# 4496028            CUNDINAMARCA                       None                 M
# 4496029                  BOYACA                       None                 M
# 4496030                 BOLIVAR                       None                 F
# 4496031                 BOLIVAR                       None                 M
#
#         estudiante_municipio puntaje_ingles  puntaje_matematicas  \
# 0        CARTAGENA DE INDIAS           54.0                 48.0
# 1                  GUATAVITA           46.0                 70.0
# 2                BOGOTÁ D.C.           66.0                 47.0
# 3        CARTAGENA DE INDIAS           71.0                 47.0
# 4                     ARJONA           41.0                 38.0
# ...                      ...            ...                  ...
# 4496027       SAN ESTANISLAO           38.0                 49.0
# 4496028                 CHÍA           90.0                 77.0
# 4496029            ZETAQUIRA           52.0                 50.0
# 4496030             PINILLOS           32.0                 44.0
# 4496031  CARTAGENA DE INDIAS           45.0                 41.0
#
#          puntaje_sociales_ciudadanas  puntaje_ciencias_naturales  \
# 0                               62.0                        60.0
# 1                               62.0                        63.0
# 2                               45.0                        53.0
# 3                               52.0                        54.0
# 4                               32.0                        40.0
# ...                              ...                         ...
# 4496027                         48.0                        49.0
# 4496028                         57.0                        84.0
# 4496029                         45.0                        53.0
# 4496030                         44.0                        41.0
# 4496031                         46.0                        56.0
#
#          puntaje_lectura_critica  puntaje_global
# 0                           56.0           282.0
# 1                           57.0           308.0
# 2                           49.0           249.0
# 3                           56.0           268.0
# 4                           44.0           193.0
# ...                          ...             ...
# 4496027                     55.0           247.0
# 4496028                     64.0           360.0
# 4496029                     50.0           248.0
# 4496030                     43.0           211.0
# 4496031                     52.0           242.0
#
# [4496032 rows x 21 columns]
